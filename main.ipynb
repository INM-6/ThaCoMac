# %%
# import internal packages
import semi_automated_literature_search as LS
import semi_automated_information_search as IS
import file_path_management
import public_library as PL
import automatic_filtering as AF
# Out:
# 10.1016/j.neuroscience.2007.02.033

# %% [markdown]
# In the next cell, we present all parameters that might have an effect on the search results, including:<br>
# 1. searching keyword lexicon
# 2. on-topic keyword lexicon
# 3. academic databases
# 4. seed papers
# 5. connectome database and
# 6. connectome database queries
# 7. ChatPDF queries for relatedness of topic

# %%
# parameters

# searching keyword lexicon
# (macaque OR Macaque) AND (thalamocortical OR thalamocortical OR corticothalamic OR 'cortico-thalamic' OR thalamus OR cortex)
search_kws_lexicon = 'macaque AND (thalamus OR thalamocortical OR thalamo-cortical)'

# academic databases
# Google Scholar: 'https://scholar.google.com/'
# 78300 results
# Web of Science: 'https://www.webofscience.com/wos/woscc/advanced-search' # can be exported to excel file
# 961 results
# PubMed Central PMC: 'https://pubmed.ncbi.nlm.nih.gov/advanced/' # can be exported to .csv file and abstract.txt file
# 2448 results
# Europe PMC = 'https://europepmc.org/advancesearch' # can be exported to .csv file or abstract and full open access file .xml
# 5129 results
acad_dbs = ['Google Scholar', 'Web of Science', 'PubMed_Central_PMC', 'Europe_PMC']

# initial urls for specified searching keyword lexicon and all academic databases
init_urls = {
             'gs': 'https://scholar.google.com/scholar?start=0&q=macaque+thalamus+OR+thalamocortical+OR+thalamo-cortical&hl=en&as_sdt=1,5',
             'wos': 'https://www.webofscience.com/wos/woscc/summary/79530a3c-47d5-4dd0-9b7d-b1d92fd11882-98d8472a/relevance/1',
             'pubmed': 'https://pubmed.ncbi.nlm.nih.gov/?term=(((thalamus)%20OR%20(thalamocortical))%20OR%20(thalamo-cortical))%20AND%20(macaque)&sort=&page=1',
             'eupmc': 'https://europepmc.org/search?query=%28%22macaque%22%20AND%20%28%22thalamus%22%20OR%20%22thalamocortical%22%20OR%20%22thalamo-cortical%22%29%20%29%20AND%20%28LANG%3A%22eng%22%20OR%20LANG%3A%22en%22%20OR%20LANG%3A%22us%22%29&page=1'
            }

# on-topic keyword lexicon
on_topic_kws = ['thalamocortical', 'thalamo-cortical', 'corticothalamic', 'cortico-thalamic',
                'tracing', 'tracer', 'tract tracing', 'tract-tracing', 'axonal tracing', 'neural tracing', 'anatomical tracing', 'anatomical neural tracing',
                'connection', 'projection', 'connectivity', 'connectome', 
                'thalamus', 'cortex', 'thalamic', 'cortical']

# seed papers specification
seed_papers = []

# connectome database and queries specification
# we search the CoCoMac
connec_db = ''
connec_db_quries = []

# ChatGPT, queries for relatedness of topic
ChatGPT_related_queries = ['Does the given text include information of thalamocotical connection?', 
                           'Does the given text include information of connection between thalamus and cortex?']

# meta categories, keywords, and correspond queries
meta_categ = ['DOI', 'Publication_link', 'pdf_link', 'Authors', 'Year', 'Country', 'Affiliation', 
              'Title', 'Abstract', 'Keywords', 
              'Thalamic_parcellation_scheme', 'Cortical_parcellation_scheme', 
              'Thalamic_area_focused', 'Cortical_area_focused',
              'Steriotactic_axis', 'Type_of_data']
meta_categ_kws = []
meta_categ_quries = []

# %%
# all the file paths in file_path_management.py
# project_folder
# gs_poten_urls
# wos_poten_urls
# pubmed_pmc_poten_urls
# eupmc_poten_urls
# path_poten_csv
# path_related_urls
# path_related_csv
# pdf_folder_path
# seed_paper_urls
# connec_db_urls

# %%
# main program
if __name__ == "__main__":
    # first we need to search all related literature that might include data or information of thalamocortical connections
    # search for potentially related literature using the listed 3 methods
    
    # setting headers and proxies
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}
    http_proxy  = "http://103.148.39.50:83"
    https_proxy = "https://47.254.158.115:20201"
    proxy = {"http": http_proxy, "https": https_proxy}
    # end of setting header and proxies
    
    # method 1: search acdemic databases using keywords
    LS.search_acad_dbs(acad_dbs, init_urls, headers, proxy)
    '''
    # method 2: spanning citations of seed papers
    LS.span_citations(seed_papers, num_span_time, headers, proxy)
    
    # method 3: search existing connectome databases
    LS.search_conne_db(connec_db, connec_db_quries)
    '''
# Out:
# Searching Google Scholar...
# <!DOCTYPE html>
# <html><head><title>Google Scholar</title><meta content="text/html;charset=utf-8" http-equiv="Content-Type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="always" name="referrer"/><meta content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=2" name="viewport"/><meta content="telephone=no" name="format-detection"/><link href="/favicon.ico" rel="shortcut icon"/><style>html,body,form,table,div,h1,h2,h3,h4,h5,h6,img,ol,ul,li,button{margin:0;padding:0;border:0;}table{border-collapse:collapse;border-width:0;empty-cells:show;}html,body{height:100%}#gs_top{position:relative;box-sizing:border-box;min-height:100%;min-width:964px;-webkit-tap-highlight-color:rgba(0,0,0,0);}#gs_top>*:not(#x){-webkit-tap-highlight-color:rgba(204,204,204,.5);}.gs_el_ph #gs_top,.gs_el_ta #gs_top{min-width:320px;}#gs_top.gs_nscl{position:fixed;width:100%;}body,td,input,button{font-size:13px;font-family:Arial,sans-serif;line-height:1.24;}body{background:#fff;color:#222;-webkit-text-size-adjust:100%;-moz-text-size-adjust:none;}.gs_gray{color:#777777}.gs_red{color:#dd4b39}.gs_grn{color:#006621}.gs_lil{font-size:11px}.gs_med{font-size:16px}.gs_hlt{font-weight:bold;}a:link{color:#1a0dab;text-decoration:none}a:visited{color:#660099;text-decoration:none}a:hover,a:hover .gs_lbl{text-decoration:underline}a:active,a:active .gs_lbl,a .gs_lbl:active{color:#d14836}.gs_el_tc a:hover,.gs_el_tc a:hover .gs_lbl{text-decoration:none}.gs_pfcs a:focus,.gs_pfcs button:focus,.gs_pfcs input:focus,.gs_pfcs label:focus{outline:none}.gs_a,.gs_a a:link,.gs_a a:visited{color:#006621}.gs_a a:active{color:#d14836}a.gs_fl:link,.gs_fl a:link{color:#1a0dab}a.gs_fl:visited,.gs_fl a:visited{color:#660099}a.gs_fl:active,.gs_fl a:active{color:#d14836}.gs_fl{color:#777777}.gs_ctc,.gs_ctu{vertical-align:middle;font-size:11px;font-weight:bold}.gs_ctc{color:#1a0dab}.gs_ctg,.gs_ctg2{font-size:13px;font-weight:bold}.gs_ctg{color:#1a0dab}a.gs_pda,.gs_pda a{padding:7px 0 5px 0}.gs_alrt{background:#f9edbe;border:1px solid #f0c36d;padding:0 16px;text-align:center;box-shadow:0 2px 4px rgba(0,0,0,.2);border-radius:2px;}.gs_alrt:empty{display:none;}.gs_spc{display:inline-block;width:12px}.gs_br{width:0;font-size:0}.gs_ibl{display:inline-block;}.gs_scl:after{content:"";display:table;clear:both;}.gs_ind{padding-left:8px;text-indent:-8px}.gs_ico,.gs_icm{display:inline-block;background:no-repeat url(/intl/en/scholar/images/1x/sprite_20161020.png);background-position:-23px -161px;background-size:169px;width:21px;height:21px;}@media(-webkit-min-device-pixel-ratio:1.5),(min-resolution:144dpi){.gs_ico,.gs_icm{background-image:url(/intl/en/scholar/images/2x/sprite_20161020.png);}}.gs_el_ta .gs_nta,.gs_ota,.gs_el_ph .gs_nph,.gs_oph{display:none}.gs_el_ta .gs_ota,.gs_el_ph .gs_oph{display:inline}.gs_el_ta div.gs_ota,.gs_el_ph div.gs_oph{display:block}.gs_sth_g{visibility:hidden;max-height:0;}.gs_sth_vis .gs_sth_g{max-height:1000px;}.gs_sth_vis .gs_sth_b{position:fixed;top:0;}.gs_sth_trk .gs_sth_b{position:absolute;top:auto;}@keyframes gs_anm_spin{0%{transform:rotate(0deg);}100%{transform:rotate(360deg);}}.gs_invis{visibility:hidden;}.gs_rimg{display:block;background-color:#e5e5e5;border-radius:50%;overflow:hidden;position:relative;z-index:1;}.gs_rimg>img{position:absolute;margin:auto;left:0;top:0;bottom:0;right:0;}.gs_in_txtw{display:inline-block;vertical-align:middle;}.gs_in_txtb{display:block;}.gs_in_txt{color:#000;background-color:#fff;font-size:16px;box-sizing:border-box;height:29px;line-height:23px;border:1px solid #d9d9d9;border-top-color:#c0c0c0;padding:3px 6px 1px 8px;border-radius:1px;outline:none;-webkit-appearance:none;-moz-appearance:none;}.gs_el_tc .gs_in_txt{font-size:18px;}.gs_in_txtb .gs_in_txt{width:100%;}.gs_in_rnd .gs_in_txt{border-radius:14.5px;padding:3px 12px 1px 12px;}.gs_in_txt:hover{border-color:#b9b9b9;border-top-color:#a0a0a0;box-shadow:inset 0 1px 2px rgba(0,0,0,.1);}.gs_in_txte .gs_in_txt{border-color:#dd4b39;}.gs_in_txt:focus{border-color:#4d90fe;box ...
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# var m,aa=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}},q=function(a){var b="undefined"!=typeof Symbol&&Symbol.iterator&&a[Symbol.iterator];if(b)return b.call(a);if("number"==typeof a.length)return{next:aa(a)};throw Error(String(a)+" is not an iterable or ArrayLike");},ba="function"==typeof Object.create?Object.create:function(a){var b=function(){};b.prototype=a;return new b},ca="function"==typeof Object.defineProperties?Object.defineProperty:function(a,
# b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a},da=function(a){a=["object"==typeof globalThis&&globalThis,a,"object"==typeof window&&window,"object"==typeof self&&self,"object"==typeof global&&global];for(var b=0;b<a.length;++b){var c=a[b];if(c&&c.Math==Math)return c}throw Error("Cannot find global object");},ea=da(this),t=function(a,b){if(b)a:{var c=ea;a=a.split(".");for(var d=0;d<a.length-1;d++){var e=a[d];if(!(e in c))break a;c=c[e]}a=a[a.length-1];d=c[a];b=b(d);
# b!=d&&null!=b&&ca(c,a,{configurable:!0,writable:!0,value:b})}},fa;if("function"==typeof Object.setPrototypeOf)fa=Object.setPrototypeOf;else{var ha;a:{var ia={a:!0},ja={};try{ja.__proto__=ia;ha=ja.a;break a}catch(a){}ha=!1}fa=ha?function(a,b){a.__proto__=b;if(a.__proto__!==b)throw new TypeError(a+" is not extensible");return a}:null}
# var ka=fa,la=function(a,b){a.prototype=ba(b.prototype);a.prototype.constructor=a;if(ka)ka(a,b);else for(var c in b)if("prototype"!=c)if(Object.defineProperties){var d=Object.getOwnPropertyDescriptor(b,c);d&&Object.defineProperty(a,c,d)}else a[c]=b[c];a.Pb=b.prototype};t("Math.trunc",function(a){return a?a:function(b){b=Number(b);if(isNaN(b)||Infinity===b||-Infinity===b||0===b)return b;var c=Math.floor(Math.abs(b));return 0>b?-c:c}});
# var ma=function(a){a=Math.trunc(a)||0;0>a&&(a+=this.length);if(!(0>a||a>=this.length))return this[a]};t("Array.prototype.at",function(a){return a?a:ma});var u=function(a){return a?a:ma};t("Int8Array.prototype.at",u);t("Uint8Array.prototype.at",u);t("Uint8ClampedArray.prototype.at",u);t("Int16Array.prototype.at",u);t("Uint16Array.prototype.at",u);t("Int32Array.prototype.at",u);t("Uint32Array.prototype.at",u);t("Float32Array.prototype.at",u);t("Float64Array.prototype.at",u);
# t("String.prototype.at",function(a){return a?a:ma});var na=function(a){var b=typeof a;return"object"==b&&null!=a||"function"==b},pa=function(a,b){var c=Array.prototype.slice.call(arguments,1);return function(){var d=c.slice();d.push.apply(d,arguments);return a.apply(this,d)}};var qa=function(){this.aa=this.aa;this.ka=this.ka};qa.prototype.aa=!1;qa.prototype.isDisposed=function(){return this.aa};qa.prototype.Ka=function(){this.aa||(this.aa=!0,this.pa())};qa.prototype.pa=function(){if(this.ka)for(;this.ka.length;)this.ka.shift()()};var ra=function(){};function v(a,b){a.classList.add(b)}function w(a,b){a.classList.remove(b)}function x(a,b){return a.classList?a.classList.contains(b):!1}function y(a,b,c){c=void 0!==c?c:!x(a,b);(c?v:w)(a,b);return c};function z(a){return 0<=(navigator.userAgent||"").indexOf(a)}var sa=z("iPhone")||z("iPad")||z("iPod"),ta=z("iPhone")||z("Android")&&z("Mobile");function ua(){if(void 0===b){var a=window.screen;a={width:window.innerWidth,height:window.innerHeight,Nb:a.width,Mb:a.height}}else a=b;var b=a;a=b.width;var c=b.height,d=b.Nb;b=b.Mb;var e=4;if(600>a||48E4>d*b||ta)e=1;else if(982>a)e=2;else if(1136>a||590>c)e=3;return e}var va,wa=/[?&]tc=([01])/.exec(location.search||"");
# va=wa?0<+wa[1]:z("Android")?!0:window.matchMedia&&window.matchMedia("(pointer)").matches?window.matchMedia("(pointer:coarse)").matches:!z("Firefox")||z("Mobile")||z("Tablet")?sa||"ontouchstart"in window||0<(navigator.msMaxTouchPoints||0):!1;function xa(){if(void 0==ya){ya=!1;try{var a=Object.defineProperty({},"passive",{get:function(){ya=!0}});window.addEventListener("testPassive",ra,a);window.removeEventListener("testPassive",ra,a)}catch(b){}}return ya}var ya;var za=function(a){this.ea=a},Aa=new za("DIV"),Ba=new za("INPUT"),Ca=new za("SCRIPT"),Da=new za("STYLE");function B(a){return document.getElementById(a)}function E(a){return a.id||(a.id="gs_id"+Ea++)}function G(a,b){return a.getAttribute(b)||""}function Fa(a){a=(void 0===a?null:a)||document.body;return"rtl"==(a?window.getComputedStyle(a,null):null).direction}
# function Ga(a,b){var c=[];a=a.elements;for(var d=a.length,e=0;e<d;e++){var f=a[e],g=encodeURIComponent(f.name||""),h=f.type;!g||b&&!b(f)||f.disabled||!("checkbox"!=h&&"radio"!=h||f.checked)||c.push(g+"="+encodeURIComponent(f.value||""))}return c.join("&")}function Ha(a,b){var c=a.elements[b];c||(c=document.createElement(Ba.ea),c.type="hidden",c.name=b,a.appendChild(c));return c}function Ia(a){a.match(Ja)&&(window.location.href=a)}
# function Ka(a){var b=B(a);b||(b=document.createElement(Da.ea),b.id=a,document.head.appendChild(b));return b}function Ma(a){if(!B("gs_hats")){var b=document.createElement(Ca.ea);b.id="gs_hats";b.src="https://www.gstatic.com/feedback/js/help/prod/service/lazy.min.js";b.onload=a;document.body.appendChild(b)}}function Na(a){return"transform:scale(1,"+a+");"}function Oa(a){return"transform:translate(0,"+a+"px);"}var Ea=100,Pa=/\S+/g,Ja=/^(?:https?:|[^:/?#]*(?:[/?#]|$))/i,Qa=/^(?:#|\/[a-z0-9_-]*(?:[?].*)?$)/i;function J(){return Date.now()}function Ra(a){return a.hasOwnProperty("gs_uid")?a.gs_uid:a.gs_uid=++Sa}var Sa=0;function Ta(a){var b=[];a=q(a);for(var c=a.next();!c.done;c=a.next())c=c.value.charCodeAt(0),b.push(32>c||126<=c?c:String.fromCharCode(32+(c-32+47)%94));return b.join("")};var K=function(){this.A=[];this.fa={};this.ya=this.K=0};K.prototype.add=function(a){var b=Ra(a);this.fa[b]||(this.A.push(a),this.fa[b]=this.A.length,++this.K)};K.prototype.remove=function(a){a=Ra(a);var b=this.fa[a];b&&(this.A[b-1]=null,delete this.fa[a],2*--this.K<this.A.length&&!this.ya&&Ua(this))};K.prototype.notify=function(a){var b=this.A;try{++this.ya;for(var c=0;c<b.length;c++){var d=b[c];d&&d.apply(null,arguments)}}finally{!--this.ya&&2*this.K<b.length&&Ua(this)}};K.prototype.getSize=function(){return this.K};
# var Ua=function(a){var b=a.A,c=b.length;a=a.fa;for(var d=0,e=0;e<c;e++){var f=b[e];f&&(b[d]=f,a[Ra(f)]=++d)}b.length=d};function L(a,b,c,d,e){Va(a,b,c,void 0===d?!1:d,void 0===e?!1:e,Wa)}function M(a,b,c,d){Va(a,b,c,void 0===d?!1:d,!1,Xa)}function Ya(a,b,c,d,e){function f(g){M(a,b,f,d);c(g)}d=void 0===d?!1:d;L(a,b,f,d,void 0===e?!1:e);return f}function Za(a,b,c,d,e){var f=Ya(a,b,function(h){clearTimeout(g);c(h)}),g=setTimeout(function(){M(a,b,f);e&&e()},d)}function N(a){$a?$a.add(a):a()}
# var ab=window.requestAnimationFrame?function(a){window.requestAnimationFrame(a)}:function(a){setTimeout(function(){return a(window.performance&&performance.now?performance.now():J())},33)};function bb(a){a.stopPropagation();a.preventDefault()}function cb(a){return(a.ctrlKey?1:0)|(a.altKey?2:0)|(a.metaKey?4:0)|(a.shiftKey?8:0)}function Wa(a,b,c,d,e){var f=a.addEventListener;e=e&&xa();f.call(a,b,c,e?{passive:e,capture:d}:d)}function Xa(a,b,c,d){a.removeEventListener(b,c,d)}
# function Va(a,b,c,d,e,f){if("string"===typeof b)f(a,b,c,d,e);else for(var g=b.length,h=0;h<g;h++)f(a,b[h],c,d,e)}function db(){$a.notify();$a=null}function eb(){"complete"==document.readyState&&(M(document,"readystatechange",eb),db())}var $a,fb=!!document.attachEvent,gb=document.readyState;if(fb?"complete"!=gb:"loading"==gb)$a=new K,fb?L(document,"readystatechange",eb):Ya(document,"DOMContentLoaded",db);
# function hb(){Ya(document,["mousedown","touchstart"],function(){y(document.documentElement,"gs_pfcs",!0);L(document,"keydown",ib,!0)},!0,!0)}function ib(a){9==a.keyCode&&(y(document.documentElement,"gs_pfcs",!1),M(document,"keydown",ib,!0),hb())}hb();function jb(a,b,c,d,e){var f=B(a);kb(f,function(){v(f,"gs_vis");b&&b()},function(){w(f,"gs_vis");c&&c()},d,e)}function lb(a){a=O[a]||[0];return a[a.length-1]}
# function kb(a,b,c,d,e,f){f=void 0===f?"":f;var g=E(a),h=lb(g);if(!h||h<lb(f)){var k=document.activeElement;f=B(f);mb(nb(f||a),!0);b&&b();ob.push(function(l){O[g].pop();O[g].length||delete O[g];if(!l){(l=e)||k==document.body||(l=k);var n=document.activeElement;if(l)try{l.focus()}catch(p){}else n&&a.contains(n)&&n.blur()}c&&c()});O[g]||(O[g]=[]);O[g].push(ob.length);k&&a.contains(k)||setTimeout(function(){var l=d,n=l&&"text"==l.type;if(!l||n&&va)l=a;try{l.focus(),n&&(l.value=l.value)}catch(p){}},0)}}
# function P(a){mb((lb(a)||1E6)-1,!1)}function pb(a){a=void 0===a?!1:a;ob.pop()(a)}function mb(a,b){for(b=void 0===b?!1:b;ob.length>a;)pb(b||ob.length>a+1)}function nb(a){for(var b=0;a&&!(b=lb(a.id));)a=a.parentNode;return b}var ob=[],O={};L(document,"click",function(a){var b=ob.length;b&&!cb(a)&&b>nb(a.target)&&pb(!0)});L(document,"keydown",function(a){27==a.keyCode&&!cb(a)&&ob.length&&pb()});
# L(document,"focus",function(a){var b=ob.length;if(b)for(var c=nb(a.target);c<b;){var d="",e;for(e in O)if(lb(e)==b){d=e;break}a:{d=(B(d).getAttribute("data-wfc")||"").match(Pa)||[];for(var f=0;f<d.length;f++){var g=B(d[f]);if(g&&g.offsetWidth){d=g;break a}}d=void 0}if(d){bb(a);d.focus();break}else pb(!0),--b}},!0);function qb(a,b,c,d){if((void 0===d?0:d)||!(c in rb)){a=a&&a.getItem(c);if(a)try{var e=JSON.parse(a)}catch(f){}b[c]=e}return b[c]}function sb(a,b,c,d){b[c]=d;try{a&&a.setItem(c,JSON.stringify(d))}catch(e){}}function tb(a,b){return qb(ub,rb,a,void 0===b?!1:b)}var rb={},ub,vb={},wb;try{ub=window.localStorage,wb=window.sessionStorage}catch(a){};function xb(a){return"object"==typeof a?a:null}function yb(){var a=zb(),b=Ab();b=Bb(b);a=Cb(a);a=Db(a)||"#";Eb=xb(b);Fb?window.history.replaceState(b,"",a):window.location.replace(a)}function Gb(a){var b=[],c;for(c in a)b.push(encodeURIComponent(c)+"="+encodeURIComponent(a[c]));return b.sort().join("&")}function Db(a){return(a=Gb(a))?"#"+a:""}
# function Hb(a){var b={};a=a.split("&");for(var c=0;c<a.length;c++){var d=a[c],e=d.indexOf("=");if(e+1){var f=d.substr(0,e);d=d.substr(e+1)}else f=d,d="";f&&(b[decodeURIComponent(f)]=decodeURIComponent(d))}return b}function Ib(){var a=window.location.hash,b=a.indexOf("#")+1;return Hb(b?a.substr(b):"")}function Jb(a){var b=a.indexOf("?")+1;a=b?a.substr(b):"";b=a.indexOf("#");return Hb(b+1?a.substr(0,b):a)}function Kb(a,b){for(var c in b){var d=b[c];void 0!==d?a[c]=d:delete a[c]}}
# function Cb(a){var b=Ib();Kb(b,a);return b}function Bb(a){var b=Eb||xb(window.history.state),c={},d;for(d in b)c[d]=b[d];Kb(c,a);return c}function Lb(){setTimeout(function(){if(!Mb){var a=window.history.state;Mb=!0;Eb=xb(a);Nb.notify()}Ob=!1},0)}var Nb=new K,Eb,Mb=!1,Ob=!0,Fb="pushState"in window.history,Pb;
# if("undefined"==typeof GSP)Pb=!1;else{var Qb=.001*J(),Rb=GSP.eventId,Sb=!1,Tb=qb(wb,vb,"nh",!1);Tb instanceof Array||(Tb=[]);for(var Ub=Tb.length,Vb=0,Wb=0;Wb<Ub;Wb++){var Xb=Tb[Wb];if(Xb instanceof Array&&2==Xb.length){var Yb=Xb[1]==Rb;Sb=Sb||Yb;10>=Ub-Wb&&+Xb[0]>Qb-86400&&!Yb&&(Tb[Vb++]=Xb)}}Tb.length=Vb;Tb.push([Qb,Rb]);sb(wb,vb,"nh",Tb);Pb=Sb}var Zb=Pb;"onpageshow"in window?L(window,"pageshow",Lb):N(Lb);
# L(window,Fb?"popstate":"hashchange",function(a){"loading"!=document.readyState&&(a=a.state,Mb=!0,Eb=xb(a),Nb.notify())});function $b(){ac&&(M(B("gs_alrt_l"),"click",ac),ac=void 0)}function bc(a){var b=void 0===b?"":b;var c=void 0===c?"":c;var d=void 0===d?[]:d;B("gs_alrt_m").innerHTML=a;cc().action=c.match(Ja)?c:"";a=B("gs_alrt_l");a.textContent=b;b=B("gs_alrt_h");b.innerHTML="";for(var e in d)c=document.createElement("input"),c.type="hidden",c.name=e,c.value=d[e],b.appendChild(c);$b();y(a,"gs_fm_s",!0);dc()}
# function dc(){var a=cc();v(a,"gs_anm");v(a,"gs_vis");L(document,"click",ec);clearTimeout(fc);fc=setTimeout(ec,4E3);++gc;setTimeout(hc,0)}function ec(){gc||(M(document,"click",ec),clearTimeout(fc),fc=void 0,$b(),w(cc(),"gs_vis"))}function cc(){return B("gs_alrt")}function hc(){gc=0}var fc,gc=0,ac;N(function(){var a=B("gs_alrt_m");a&&(a.innerHTML&&!Zb&&dc(),L(window,"pagehide",function(){gc=0;ec();w(cc(),"gs_anm")}))});function Q(a,b,c){b=void 0===b?ic:b;c=void 0===c?!1:c;b.length=0;a.normalize&&(a=a.normalize("NFKD").replace(jc,""));return a.toLowerCase().replace(kc,function(d,e){b.length||e&&b.push(0);b.push(d.length);return e&&(!c||e+d.length<a.length)?" ":""})}function lc(a,b,c,d,e){var f=c.indexOf(a),g="",h="";0<f&&(f=c.indexOf(" "+a));!(a&&f+1)||void 0!==e&&e&&f||(f+=" "==c[f],g=mc(c.substr(0,f),b,d),h=mc(c.substr(0,f+a.length),b,d).substr(g.length));return[g,h,b.substr(g.length+h.length)]}
# function mc(a,b,c){var d=a.length;for(a=a.split(" ").length;a--;)d+=(c[a]||0)-1;return b.substr(0,d+1)}var ic=[],jc=/[\u0300-\u036f]+/g,kc=RegExp("[\\s\x00-/:-@[-`{-\u00bf\u2000-\u206f\u2e00-\u2e42\u3000-\u303f\uff00-\uff0f\uff1a-\uff20\uff3b-\uff40\uff5b-\uff65]+","g"),nc=/^[\d\s]*[\u0590-\u08ff\ufb1d-\ufdff\ufe70-\ufefc]/;var oc=function(a,b,c,d,e,f,g){e=void 0===e?[]:e;this.C=a;this.source=b;this.Oa=void 0===c?"":c;this.B=void 0===d?"":d;this.X=e;this.Ib=void 0===f?"":f;this.Sa=void 0===g?"":g};var pc=function(){this.ab=100;this.K=0;this.W=this.O=null;this.ia=Object.create(null)};pc.prototype.get=function(a){if(a=this.ia[a])return qc(this,a),a.value};pc.prototype.set=function(a,b){var c=this.ia[a];c?(c.value=b,qc(this,c)):(this.K>=this.ab&&(delete this.ia[this.W.key],this.W=this.W.V,this.W.ja=null,--this.K),c=this.ia[a]={key:a,value:b,ja:this.O,V:null},this.O?this.O.V=c:this.W=c,this.O=c,++this.K)};
# var qc=function(a,b){var c=b.ja,d=b.V;d&&((d.ja=c)?c.V=d:a.W=d,a.O.V=b,b.ja=a.O,b.V=null,a.O=b)};function rc(a,b,c){var d=new XMLHttpRequest;d.onreadystatechange=function(){if(4==d.readyState){var e=d.status,f=d.responseText,g=d.getResponseHeader("Content-Type"),h=d.responseURL,k=window.location,l=k.protocol;k="//"+k.host+"/";h&&h.indexOf(l+k)&&h.indexOf("https:"+k)&&(e=0,g=f="");c(e,f,g||"")}};d.open(b?"POST":"GET",a,!0);d.setRequestHeader("X-Requested-With","XHR");b&&d.setRequestHeader("Content-Type","application/x-www-form-urlencoded");b?d.send(b):d.send();return d}
# function sc(a){a&&(a.onreadystatechange=function(){},a.abort())};var tc=function(a,b){this.Kb=a;this.Va=b;this.da=this.ca=0;this.Ba=this.Ca="";this.Da=void 0;this.Ja=new pc},wc=function(a,b,c){var d=b?a.Ja.get(uc(a,b,c)):[];d?a.Va(b,c,d):(a.Ca=b,a.Ba=c,10<=a.ca||3<=a.da||(a.ca?void 0!==a.Da||(a.Da=setTimeout(function(){vc(a)},100<<Math.max(a.ca-4,0))):vc(a)))},vc=function(a){a.Da=void 0;var b=a.Ca,c=a.Ba;a.Ca=a.Ba="";if(b){++a.ca;var d=new XMLHttpRequest;d.onreadystatechange=function(){if(d&&4==d.readyState){var e=d.status;200==e&&a.wa(b,c,d.responseText);d=null;
# xc(a,e)}};d.ontimeout=function(){d&&(d=null,xc(a))};d.open("GET",uc(a,b,c),!0);d.timeout=3E4;d.send()}},xc=function(a,b){b=void 0===b?0:b;--a.ca;var c=3*(403==b)+(499<b&&600>b);a.da+=c;c&&setTimeout(function(){a.da-=c},3E4)};
# tc.prototype.wa=function(a,b,c){try{var d=JSON.parse(c)}catch(r){}if(d&&"object"==typeof d&&(c=d.l,c instanceof Array)){d=[];for(var e=c.length,f=0;f<e;f++){var g=d,h=g.push,k=""+c[f],l=k.indexOf("|");var n=k.substr(0,l);var p=Q(n);k=k.substr(l+1);l=[];n=new oc(k,0,"",Q(k,l),l,n,p);h.call(g,n)}this.Ja.set(uc(this,a,b),d);this.Va(a,b,d)}};var uc=function(a,b,c){return"/scholar_complete?"+encodeURIComponent(a.Kb)+"="+encodeURIComponent(b)+"&"+c};var zc=function(a){this.Wa="H:"+a;this.G=[];this.Hb=.001*J();a=tb(this.Wa);a instanceof Array||(a=[]);for(var b=this.G,c={"":1},d=0;d<a.length&&50>b.length;d++){var e=new yc(a[d]);c.hasOwnProperty(e.B)||(c[e.B]=1,b.push(e))}};
# zc.prototype.add=function(a,b,c){c=(void 0===c?0:c)||.001*J();b=(void 0===b?0:b)||c;a=new yc([0,0,a]);if(a.B){for(var d=this.G,e=d.length,f=0;f<e&&d[f].B!=a.B;)++f;f<e||d.push(a);e=d[f];if(!(2>b-e.F)){e.F=b;e.C=a.C;e.X=a.X;for(e.H=Math.min(e.H+Ac(b),10*Ac(c));f&&Bc(d[f],d[f-1]);)a=d[f],d[f]=d[f-1],d[--f]=a;d.splice(50,1);Cc(this)}}};zc.prototype.remove=function(a){for(var b=this.G,c=b.length,d=0;d<c;d++)if(b[d].C==a){b.splice(d,1);Cc(this);break}};
# var Cc=function(a){for(var b=[],c=a.G,d=c.length,e=0;e<d;e++)b.push(c[e].encode());sb(ub,rb,a.Wa,b)};function Ac(a){return Math.exp(.0231*(Math.max(a-1422777600,0)/86400|0))}var yc=function(a){a instanceof Array||(a=Dc);this.F=+a[0]||0;this.H=+a[1]||0;this.C=""+a[2];this.X=[];this.B=Q(this.C,this.X,!0)};yc.prototype.encode=function(){return[this.F,this.H,this.C]};
# var Bc=function(a,b){var c=a.H-b.H;return 0<c||!c&&a.F>b.F},Dc=[0,0,""],Ec=function(a,b,c){this.F=a;this.H=b;this.C=c},Fc=function(a,b){var c=a.H-b.H;return 0<c||!c&&a.F>b.F};var Gc=function(a){this.D=a};function Hc(a){var b=document.createElement("b");b.textContent=a;return b};var Ic=function(a,b,c){this.type=a;this.currentTarget=this.target=b;this.j=void 0===c?null:c;this.Ea=!1};Ic.prototype.stopPropagation=function(){this.j&&this.j.stopPropagation();this.Ea=!0};var S=function(a){a.j&&bb(a.j);a.Ea=!0};var T=function(a,b){this.Ha=a;this.Gb=b},Jc=function(a,b,c){this.Ha=a;this.types=b;this.listener=c};function Kc(a,b){U(a,"click",b)}function Lc(a,b){var c=b.length;if(c){var d=Ra(a),e=Mc[d];if(!e){e=Mc[d]=[];d=Nc(b[0].Ha);for(var f in d){var g=Oc[f];g||(g=Oc[f]=Object.create(null));for(var h in d[f]){var k=g[h];k||(k=g[h]=[]);k.push(a)}}Pc(a,e,b[0],Qc);for(f=1;f<c;f++)Pc(a,e,b[f],Rc)}}}function V(a,b,c){Sc(new Ic(a,b,void 0===c?null:c))}
# function U(a,b,c){var d=Tc;"string"===typeof b&&(Uc[0]=b,b=Uc);var e=b.length;a=Nc(a);for(var f in a)for(var g in a[f])for(var h=0;h<e;h++)d(f,g,b[h],c)}function Nc(a){"string"===typeof a&&(Vc[0]=a,a=Vc);for(var b=a.length,c=Object.create(null),d=0;d<b;d++){var e=a[d],f=e.charAt(0),g=e.substr(1);if("#"!=f&&"."!=f||!g)throw Error("bad selector: "+e);(e=c[f])||(e=c[f]=Object.create(null));e[g]=!0}return c}
# function Tc(a,b,c,d){var e=Wc[c];e||("touchstart"!=c&&"mouseover"!=c&&"mouseout"!=c&&L(document,c,Xc,"focus"==c||"blur"==c),e=Wc[c]=Object.create(null));(c=e[a])||(c=e[a]=Object.create(null));(a=c[b])||(a=c[b]=new K);a.add(d)}function Xc(a){var b=a.target;b&&3==b.nodeType&&(b=b.parentNode);Sc(new Ic(a.type,b,a))}
# function Sc(a){for(var b=a.target;b&&b!=document&&!b.disabled&&!x(b,"gs_dis");){a.currentTarget=b;var c=b.id;if(c&&!Yc("#",c,a))break;c=b.classList||[];for(var d=c.length,e=0;e<d;e++)if(!Yc(".",c[e],a))return;b=b.parentNode}}function Yc(a,b,c){var d=Wc[c.type];(b=(a=d&&d[a])&&a[b])&&b.notify(c);return!c.Ea}function Pc(a,b,c,d){var e=c.Ha;c=c.Gb;for(var f in c){var g=pa(d,a,c[f]);U(e,f,g);b.push(new Jc(e,f,g))}}function Qc(a,b,c){var d=c.currentTarget;a=Zc(a,d)||a;a=$c(a,d);b.call(a,c)}
# function Rc(a,b,c){a:{for(var d=c.currentTarget;d&&d!=document;){var e=Zc(a,d);if(e){a=$c(e,d);break a}d=d.parentNode}a=void 0}a&&b.call(a,c)}function $c(a,b){var c=ad(b),d=bd[c];d||(d=bd[c]=[]);for(var e=d.length,f=0;f<e;f++){var g=d[f];if(g instanceof a)return g}b=new a(b);d.push(b);a=Ra(a);(d=cd[a])||(d=cd[a]=[]);d.push(c);return b}function Zc(a,b){var c,d=b.id;d&&(c=dd(a,c,"#",d));b=b.classList||[];d=b.length;for(var e=0;e<d;e++)c=dd(a,c,".",b[e]);return c}
# function dd(a,b,c,d){c=(d=(c=Oc[c])&&c[d])?d.length:0;for(var e=0;e<c;e++){var f=d[e];!(f===a||f.prototype instanceof a)||b&&!(f===b||f.prototype instanceof b)||(b=f)}return b}function ad(a){var b=a.getAttribute("data-duid");b||a.setAttribute("data-duid",b=""+ed++);return b}var Wc=Object.create(null),Vc=[""],Uc=[""],Oc=Object.create(null),Mc=Object.create(null),cd=Object.create(null),bd=Object.create(null),ed=100;window.gs_evt_dsp=Xc;function fd(a){if("string"===typeof a){var b=a.charAt(0),c=a.slice(1);if("#"==b)a=function(d){return d.id==c&&0<d.offsetWidth};else if("."==b)a=function(d){return x(d,c)&&0<d.offsetWidth};else throw Error("bad selector: "+a);}return a}function gd(a,b){return a&&((void 0===b?0:b)?a.lastElementChild:a.firstElementChild)}function hd(a,b){return a&&((void 0===b?0:b)?a.previousElementSibling:a.nextElementSibling)}
# function id(a){var b=void 0===b?!1:b;var c=[];for(a=hd(a,b);a;)c.push(a),a=hd(a,b);return c}function jd(a,b,c,d){d=void 0===d?!1:d;return kd(a,b,fd(c),d,!1)}function kd(a,b,c,d,e){for(var f;b&&a;){if(c(b)){if(e)return b}else for(f=gd(b,d);f;f=hd(f,d))if(e=kd(f,f,c,d,!0))return e;for(e=!0;;){if(b==a)return null;f=b.parentNode;if(b=hd(b,d))break;b=f}}return null};var W=function(a){var b=this;this.g=a.querySelector(".gs_in_ac");this.D=a.querySelector(".gs_md_ac");this.ba=this.N=!1;this.G=new zc(this.g.name);this.fb=new tc(this.g.name,function(c,d,e){d==b.la&&ld(b,c)&&(c.length>=b.ma.length||!ld(b,b.ma))&&(b.ma=c,b.Fa=e,md(b))});this.Ta=0;this.Lb=new Gc(this.D);this.Pa=[];this.Ra=[];this.ma="";this.Fa=[];this.la="";this.J=this.g.value;nd(this);L(this.g.form,["change","gs-change"],function(){nd(b)})},od=function(a){return"block"==a.D.style.display},qd=function(a){if(od(a)){var b=
# pd(a);b&&w(b,"gs_sel");a.N=a.ba=!1;a.D.style.display="none"}},rd=function(a,b,c){c=void 0===c?[]:c;a.Pa=c;c=a.G;var d=Q(b);var e=" "+d,f=d.length,g=d.split(" ").length,h=.1/Ac(c.Hb),k=c.G,l=k.length;c=[];for(var n=0;n<l;n++){var p=k[n],r=p.B,F=r.indexOf(d);if(!(0>F)){var H=10;F&&(F=r.lastIndexOf(e),H=+(0<=F));r=H*(2*(g-1)+(1+(" "==(r[F+f]||" "))))/g;F=p.H*h;if(r=d?r*F:1){p=new Ec(p.F,r,p.C);for(r=0;r<c.length&&!Fc(p,c[r]);)++r;3>r&&c.splice(r,0,p);c.splice(3,1)}}}d=[];for(e=0;e<c.length;e++)f=d,g=
# f.push,h=c[e].C,k=[],h=new oc(h,2,"",Q(h,k),k),g.call(f,h);a.Ra=d;wc(a.fb,b,a.la);md(a)},ld=function(a,b){return 0==Q(a.g.value).indexOf(Q(b))},sd=function(a){var b=a.g.value;a.J=b;nd(a);var c=[],d=a.g.getAttribute("data-iq")||"",e=a.g.getAttribute("data-is");if(d==b&&e){d=document.querySelectorAll(e);e=d.length;for(var f=0;f<e&&10>f;f++){var g=d[f];c.push(new oc(g.textContent,1,g.innerHTML))}}rd(a,b,c)},md=function(a){a.Ta++||ab(function(){a.Ta=0;var b=a.Pa;var c=a.Fa;if(b.length)b=b.slice(0,10);
# else{b=a.Ra.slice(0,3);var d=c.length&&c[0].Sa,e=d?3:10,f=b.length;if(!f||!d){for(d=Object.create(null);f--;)d[b[f].B]=!0;for(f=0;f<c.length&&b.length<e;f++){var g=c[f];d[g.B]||b.push(g)}}}c=b;var h=a.g.value,k=a.Lb.D.firstElementChild;g=k.querySelector(".gs_md_acs");b=k.querySelector("ul");e=(e=b.querySelector(".gs_sel"))?e.getAttribute("data-q"):"";f=c.length;var l=[];d=Q(h,l);b.innerHTML="";if(f){var n=c[0].Sa,p=n&&"gs_md_acp";"string"===typeof p||(p=p.join(" "));k.className!=p&&(k.className=p);
# h=lc(n,h,d,l,!0);g.textContent=h[0]+h[1];h=h[2];d=Q(h,l);for(g=0;g<f;g++){n=c[g];k=document.createElement("li");l=(n.Ib||"")+n.C;k.className="gs_md_ac_li";k.setAttribute("data-q",l);k.setAttribute("onclick","");if(n.Oa)k.innerHTML=n.Oa;else{h=lc(d,n.C,n.B,n.X);if(!h[1]){for(h=0;n.B[h]==d[h];)++h;h=lc(d.substr(0,h),n.C,n.B,n.X)}h[0]&&k.appendChild(Hc(h[0]));k.appendChild(document.createTextNode(h[1]));h[2]&&k.appendChild(Hc(h[2]));2==n.source&&(v(k,"gs_md_ac_lh"),h=document.createElement("span"),h.className=
# "gs_ico gs_ico_X gs_ico_Xt",k.appendChild(h))}l==e&&v(k,"gs_sel");b.appendChild(k)}}c=c.length&&document.activeElement==a.g;c!=od(a)&&(c?od(a)||(a.N=a.ba=!1,a.D.style.display="block"):qd(a))})},pd=function(a){return a.D.querySelector(".gs_sel")},ud=function(a,b){var c=a.g.getAttribute("data-oq")||"oq",d=a.g.form,e=d.elements[c];e||(e=document.createElement("input"),e.name=c,e.type="hidden",d.appendChild(e));e.value=a.J;a.g.value=td(b)},vd=function(a){V("gs-change",a.g)};m=W.prototype;
# m.vb=function(){var a=this.g.value;this.J!=a&&(this.J=a,rd(this,a),wd(this.g,Q(a).match(nc)?"rtl":"ltr"))};
# m.ua=function(a){if(!this.ba){var b=a.j,c=b.keyCode;b=cb(b);var d;13!=c||b?27!=c||b?38!=c&&40!=c||b?(46==c&&!b||88==c&&(1==b||4==b))&&(d=pd(this))&&x(d,"gs_md_ac_lh")&&(this.g.selectionStart||0)>=this.g.value.length&&(this.G.remove(td(d)),rd(this,this.g.value=this.J),S(a),vd(this)):(od(this)?((d=pd(this))&&w(d,"gs_sel"),(d=jd(this.D,d||this.D,".gs_md_ac_li",38==c))?(v(d,"gs_sel"),this.g.value=td(d)):this.g.value=this.J,vd(this)):sd(this),S(a)):od(this)&&(this.g.value=this.J,qd(this),S(a),vd(this)):
# ((d=pd(this))&&ud(this,d),qd(this),vd(this))}};m.va=function(){var a=this;document.activeElement==this.g?sd(this):(clearTimeout(this.za),this.za=setTimeout(function(){a.za=void 0},500))};m.ub=function(){void 0!==this.za&&sd(this)};m.ib=function(){var a=this;setTimeout(function(){qd(a)},this.N?300:0)};m.hb=function(a){this.N&&S(a)};m.sb=function(){this.ba=!0};m.rb=function(){this.ba=!1};var nd=function(a){var b=a.g,c=Ga(b.form,function(d){return d!=b});c!=a.la&&(a.la=c,a.ma="",a.Fa=[])};m=W.prototype;
# m.mb=function(a){this.N=!0;S(a)};m.nb=function(){this.N=!0};m.sa=function(){this.N=!1};m.jb=function(a){var b=a.currentTarget;if(x(a.target,"gs_ico_X"))this.G.remove(td(b)),rd(this,this.g.value=this.J);else{ud(this,b);qd(this);this.g.blur();var c=this.g.form;setTimeout(function(){c.submit()},0)}vd(this)};m.lb=function(a){a=a.currentTarget;if(!x(a,"gs_sel")){var b=pd(this);b&&w(b,"gs_sel");v(a,"gs_sel")}};m.kb=function(a){w(a.currentTarget,"gs_sel")};
# var xd=[new T(".gs_in_acw",{}),new T(".gs_in_ac",{input:W.prototype.vb,keydown:W.prototype.ua,mousedown:W.prototype.va,focus:W.prototype.ub,blur:W.prototype.ib,beforedeactivate:W.prototype.hb,compositionstart:W.prototype.sb,compositionend:W.prototype.rb}),new T(".gs_md_ac",{mousedown:W.prototype.mb,touchstart:W.prototype.nb,mouseup:W.prototype.sa,touchend:W.prototype.sa,touchcancel:W.prototype.sa}),new T(".gs_md_ac_li",{click:W.prototype.jb,mouseover:W.prototype.lb,mouseout:W.prototype.kb})];
# function td(a){return a.getAttribute("data-q")||""}function wd(a,b){a.getAttribute("dir")!=b&&(a.setAttribute("dir",b),a.parentNode.setAttribute("dir",b),a.parentNode.querySelector(".gs_md_ac").setAttribute("dir",b))}function yd(){for(var a=document.querySelectorAll(".gs_in_ac"),b=a.length,c=0;c<b;c++){var d=a[c],e=d.getAttribute("data-iq")||"";d.value=e;wd(d,Q(e).match(nc)?"rtl":"ltr");V("gs-change",d);e=d.getAttribute("data-oq")||"oq";(e=d.form.elements[e])&&d.form.removeChild(e)}};function zd(a){return!!x(a,"gs_sel")+2*!!x(a,"gs_par")}function Ad(a,b,c){c=void 0===c?!1:c;y(a,"gs_sel",1==b);y(a,"gs_par",2==b);a.setAttribute("aria-checked",Bd[b]);c||a.setAttribute("data-s",""+b)}var Bd=["false","true","mixed"];var Cd=function(a){var b=window,c=this;this.A=new K;this.Ua=0;this.Ia=[b,a,function(){c.Ua++||ab(d)},!1];var d=function(){c.Ua=0;c.A.notify()}};Cd.prototype.addListener=function(a){this.A.getSize()||L.apply(null,this.Ia);this.A.add(a)};Cd.prototype.removeListener=function(a){this.A.remove(a);this.A.getSize()||M.apply(null,this.Ia)};var Dd=new Cd("scroll"),Ed=new Cd("resize");var Fd=new K;function Gd(){var a=document.documentElement,b=ua();b={gs_el_ph:1==b,gs_el_ta:2==b,gs_el_sm:4!=b,gs_el_tc:va||1==b};var c;for(c in b){var d=b[c];if(x(a,c)!=d){var e=!0;y(a,c,d)}}e&&Fd.notify()}y(document.documentElement,"gs_el_ios",sa);Gd();Ed.addListener(Gd);L(window,["pageshow","load"],Gd);var Hd=function(a,b,c,d,e,f){this.i=a;this.Z=b;this.T=c;this.Y=d;this.Aa=e;this.S=f;this.v=null},Id=function(a,b){a.v=b},Jd=function(){this.o=[];this.m=-1};Jd.prototype.push=function(a){++this.m;this.m==this.o.length?this.o.push(a):(this.o[this.m]=a,this.o.splice(this.m+1,this.o.length-this.m))};Jd.prototype.pop=function(){--this.m};var Kd=function(a){for(var b=X;b.m>a;)P(b.top().i)},Ld=function(a,b){for(var c=0;c<a.o.length&&!(a.o[c].S>=b);++c);return c};Jd.prototype.top=function(){return this.at(this.m)};
# Jd.prototype.at=function(a){return this.o[a]||null};function Md(a,b){var c=a==X.m;X.m=a;b&&!Eb&&!xb(window.history.state)&&yb();c||Nd()}function Od(a,b,c,d){b=void 0===b?"":b;c=void 0===c?"":c;d=void 0===d?"":d;var e=X.top();e&&a==e.i&&b==e.Z&&c==e.T||(X.push(new Hd(a,b,c,d,e&&e.i==a?e.Aa+1:1,J())),b=zb(),a=Ab(),a=Bb(a),b=Cb(b),b=Db(b)||"#",Eb=xb(a),Fb?window.history.pushState(a,"",b):window.location.assign(b),Nd())}
# function Pd(a){a=Qd(B(a));return!!a&&x(a,"gs_md_wmw")&&x(document.documentElement,"gs_el_ph")}function Rd(){var a=B("gs_top"),b=document.documentElement;a=a.scrollHeight>b.clientHeight;for(var c=!1,d=0;d<=X.m&&!c;++d)c=!Pd(X.at(d).i);y(B("gs_md_s"),"gs_vis",c);c=X.m;1<=c&&(c=X.at(c-1).i,d=Pd(c),y(B(c),"gs_md_ins_vis",!d));b.style.overflowY=a&&!Pd(X.top().i)?"scroll":""}
# function Nd(){function a(){var I=c.clientHeight,C=+H.getAttribute("data-h");C||(g.style.maxHeight="none",C=f.offsetHeight);var D=f.querySelector(".gs_md_ftr");C=Math.max((I-C)/2,10);I=Math.max(I-48-(D?D.offsetHeight:0)-2*C,10);D=Pd(e);f.style.top=D?"auto":C+"px";g.style.maxHeight=D?"none":I+"px";Sd(g)}var b=X.top(),c=document.documentElement,d=B("gs_top"),e=b.i,f=B(e),g=B(e+"-bdy"),h=1200+X.m,k=B(f.getAttribute("data-cid")||f.id+"-bdy")||f,l=b.Y,n=b.T,p=b.Z,r=B("gs_md_s"),F=B(e).getAttribute("data-shd")||
# "",H=Qd(f),A=window.pageYOffset,R=p&&"#"!=p[0]&&!l,oa=0<X.m?X.at(X.m-1).i:"",La=!!O[e];R?(La?y(k,"gs_md_ldg",!0):Td(f,k,'<div class="gs_md_prg">'+B("gs_md_ldg").innerHTML+"</div>",b),V("gs-md-ldin",k)):(l&&Td(f,k,l,b),V("gs-md-lded",k));La&&e==oa||kb(f,function(){(H||f).style.zIndex=h;Ud(F);if(!La){H&&v(H,"gs_vis");v(f,"gs_vis");y(f,"gs_abt",Ob);y(r,"gs_abt",Ob);Vd(e);if(0==X.m){var I=Rd;Fd.add(I);I()}else Rd();H&&g&&(a(),Ed.addListener(a))}0==X.m&&(v(d,"gs_nscl"),d.style.top=-A+"px")},function(){La||
# (Ed.removeListener(a),H&&w(H,"gs_vis"),w(f,"gs_vis"),w(f,"gs_abt"));for(var I=X.top()?X.top().Aa:0;X.top()&&X.top().i==e;){var C=X.top();sc(C.v);C.v=null;X.pop()}if(X.top()){if(C=X.top().i,Ud(B(C).getAttribute("data-shd")||""),w(B(C),"gs_md_ins_vis"),La){a:{C=X;for(var D=C.m;0<=D;D--)if(C.o[D].i==e){C=D;break a}C=-1}D=X.at(C);(H||f).style.zIndex=1200+C;Td(f,k,D.Y,D)}}else w(r,"gs_vis"),w(r,"gs_abt");-1==X.m?(Fd.remove(Rd),c.style.overflowY="",w(d,"gs_nscl"),d.style.top="auto",window.scrollTo(0,A)):
# Rd();Wd||(0<I?window.history.go(-I):yb())},Xd(f),Yd(f),oa);R&&(sc(b.v),b.v=null,Id(b,rc(p,n,function(I,C,D){b.v=null;D=(I=200==I&&D.match(/^text\/html(;.*)?$/i))?C:Zd();Td(f,k,D,b);if(I)for(I=0;I<X.o.length;++I)D=X.at(I),e==D.i&&p==D.Z&&n==D.T&&(D.Y=C,I==X.m&&yb());V("gs-md-lded",k)})))}function Qd(a){a=a.parentNode;return x(a,"gs_md_wnw")?a:null}function Xd(a){return(a=a.getAttribute("data-ifc"))?B(a):null}function Yd(a){return(a=a.getAttribute("data-cfc"))?B(a):null}
# function Td(a,b,c,d){y(b,"gs_md_ldg",!1);for(var e=b.querySelectorAll("[data-duid]"),f=e.length,g={},h=0;h<f;h++){for(var k=ad(e[h]),l=bd[k],n=l?l.length:0,p=0;p<n;p++){var r=l[p],F=Ra(r.constructor),H=g[F];H||(H=g[F]={});H[k]=!0;r&&"function"==typeof r.Ka&&r.Ka()}delete bd[k]}for(var A in g){A=+A;e=g[A];h=(f=cd[A])?f.length:0;for(l=k=0;l<h;l++)n=f[l],n in e||(f[k++]=n);k?f.length=k:delete cd[A]}b.innerHTML=c;d.Y=c;Vd(a.id);sc(d.v);d.v=null}
# function Vd(a){if(a=document.querySelector("#"+a+">.gs_md_bdy"))a.scrollTop=a.scrollLeft=0,Sd(a)}function Sd(a){var b=a.style,c="padding"+(Fa(a)?"Left":"Right");b[c]="";var d=a.offsetWidth-a.clientWidth;2<d&&(a=parseInt(window.getComputedStyle(a,null)[c],10)||0,b[c]=Math.max(a-d,0)+"px")}function $d(){return B("gs_md_err").innerHTML}function Zd(){return'<div class="gs_md_prg"><div class="gs_alrt">'+$d()+"</div></div>"}
# function zb(){var a=X.top();return{d:a&&a.i||void 0,u:a&&a.Z||void 0,p:a&&a.T?"1":void 0,t:a&&a.S||void 0}}function Ab(){var a=X.top();return{n:a&&a.Aa||0,p:a&&a.T||"",h:a&&a.Y||""}}function Ud(a){if(ae!=a){var b=B("gs_md_s");ae&&w(b,ae);(ae=a)&&v(b,a)}}var Wd=0,ae="",X=new Jd;
# Nb.add(function(){var a=Ib(),b=a.d||"",c=b?B(b):null;++Wd;if(c){var d=a.u||"";c=0<+a.p;var e=+a.t||0,f=Eb||xb(window.history.state)||{};a=+f.n||0;var g=""+(f.p||"");f=""+(f.h||"");d.match(Qa)||(d="");for(var h=Ld(X,e),k=h;k<X.o.length;++k){var l=X.at(k);if(e<l.S&&l.i!=b)break}for(l=h-1;0<=l;--l){var n=X.at(l);if(e>n.S&&n.i!=b)break}Kd(k-1);for(k=0;k<=l;++k)n=X.at(k).i,O[n]||Md(l,!1);if(l=h<X.o.length)l=X.at(h),l=b==l.i&&d==l.Z&&c==!!l.T&&e==l.S;l?Md(h,!0):(0==a&&(Kd(-1),X=new Jd,e=J()),c!=!!g&&(d=
# g="",f=Zd()),b=new Hd(b,d,g,f,a,e),c=X,e=b.S,a=Ld(c,e),e=a<c.o.length&&e==c.at(a).S,c.o.splice(a,e?1:0,b),X.m=a,yb(),Nd())}else Kd(-1);--Wd});var be=function(a){qa.call(this);this.ha=a;this.xa=Object.create(null);this.v=null;a=a.querySelectorAll(".gs_in_txtw>input[type=text]");for(var b=a.length;b--;){var c=a[b],d=c.parentNode.querySelector(".gs_in_txts");c=c.name;d&&c&&(this.xa[c]=d.innerHTML)}};la(be,qa);be.prototype.pa=function(){sc(this.v);this.ha=this.v=null;qa.prototype.pa.call(this)};be.prototype.Bb=function(a){var b=this;S(a);if((a=this.ha)&&!this.v){var c="json=&"+Ga(a);ce(this,!0);this.v=rc(a.action,c,function(d,e){b.wa(d,e)})}};
# be.prototype.wa=function(a,b){this.v=null;ce(this,!1);var c=this.ha,d=c.getAttribute("data-alrt");if(d=d?B(d):null)d.innerHTML="";try{var e=200==a&&JSON.parse(b)}catch(p){}a=!1;e&&"object"==typeof e||(a=$d(),d?d.innerHTML=a:bc(a),e={},a=!0);c.setAttribute("data-p",""+(e.P||""));V("gs-ajax-form-done",c);if(b=e.L)Ia(""+b);else{if(b=e.M)d?d.innerHTML=b:bc(b),a=!0;b=1E6;if(d&&d.innerHTML){var f=d;b=d.getBoundingClientRect().top}d=c.elements;e=e.E;"object"==typeof e||(e=Object.create(null));for(var g in this.xa){var h=
# d[g],k=void 0,l=""+(e[g]||""),n=h.parentNode.querySelector(".gs_in_txts");y(h.parentNode,"gs_in_txte",!!l);n&&(n.innerHTML=l||this.xa[g]||"");l&&(k=h.getBoundingClientRect().top)<b&&(f=h,b=k);a=a||!!l}(c=c.getAttribute("data-d"))&&!a&&P(c);f&&f.scrollIntoView&&(0>b||b+20>window.innerHeight)&&f.scrollIntoView()}};var ce=function(a,b){a=a.ha;var c=a.getAttribute("data-bsel");a=c?document.querySelectorAll(c):a.querySelectorAll("button");for(c=a.length;c--;){var d=a[c];d.disabled=b;y(d,"gs_bsp",b)}};
# Lc(be,[new T(".gs_ajax_frm",{submit:be.prototype.Bb})]);var de=[[1,0,1],[2,0,1]];U(".gs_cb_gen","click",function(a){var b=a.currentTarget,c=zd(b),d=2==+b.getAttribute("data-s");Ad(b,de[+d][c],!0);V("gs-change",b,a.j)});U(".gs_cb_gen",["keydown","keyup"],function(a){var b=a.currentTarget,c=a.j.keyCode;"BUTTON"!=b.tagName||13!=c&&32!=c||(S(a),"keydown"==a.type&&b.click())});U([".gs_cb_gen",".gs_md_li"],"keydown",function(a){var b=a.currentTarget,c=b.tagName,d=a.j.keyCode;"BUTTON"!=c&&(32==d||13==d&&"A"!=c)&&(S(a),b.click())});var ee=["click","contextmenu","mouseup"].concat(navigator.sendBeacon?[]:["mousedown","touchstart"]),fe="",ge=null;function he(){ge=null}function ie(a){navigator.sendBeacon?navigator.sendBeacon(a):ge&&a==ge.src||((ge=new Image).src=a,setTimeout(he,1E3))}function je(){var a=Jb(document.location.href).hl||"";a="/scholar_bfnav?url="+encodeURIComponent(document.location.href)+"&hl="+encodeURIComponent(a)+"&ei="+GSP.eventId;ie(a)}N(function(){fe=Zb?"&bn=1":"";Zb&&je()});
# L(window,"pageshow",function(a){a.persisted&&(fe="&bn=1",je())});
# L(document,ee,function(a){if(!("click"==a.type&&a.button||"mouseup"==a.type&&1!=a.button)){var b,c;a:{for(a=a.target;a;){var d=a.nodeName;if("A"==d)break a;if("SPAN"==d||"B"==d||"I"==d||"EM"==d||"IMG"==d)a=a.parentNode;else break}a=null}a&&(b=a.getAttribute("href"))&&(c=a.getAttribute("data-clk"))&&(b="/scholar_url?url="+encodeURIComponent(b)+"&"+c+"&ws="+window.innerWidth+"x"+window.innerHeight+"&at=",c=encodeURIComponent,a=(a=a.getAttribute("data-clk-atid"))&&B(a),b=b+c(a&&a.innerText||"")+fe,ie(b))}},
# !1,!0);U(".gs_fm_s","click",function(a){a=a.currentTarget.getAttribute("data-fm")||"";(a=B(a))&&a.submit()});var ke=function(a){this.i=E(a.querySelector(".gs_md_d"));this.oa=E(a.querySelector(".gs_md_tb"))};m=ke.prototype;m.qa=function(a){var b=B(this.i);return void 0!==a?jd(b,b,".gs_md_li",a):null};m.open=function(a){a=this.qa(a);if(x(B(this.oa),"gs_sel"))try{a&&a.focus()}catch(c){}else{var b=B(this.oa);jb(this.i,function(){v(b,"gs_sel")},function(){w(b,"gs_sel")},a,b)}};m.close=function(){P(this.i)};m.ob=function(a){S(a);x(B(this.oa),"gs_sel")?this.close():this.open("keydown"==a.j.type?!1:void 0)};
# m.Ma=function(a){var b=a.j.keyCode;if(38==b||40==b)S(a),this.open(38==b)};m.tb=function(a){a.target.id==this.i&&this.Ma(a)};Lc(ke,[new T(".gs_md_rmb",{}),new T(".gs_md_tb",{"gs-press":ke.prototype.ob,keydown:ke.prototype.Ma}),new T(".gs_md_d",{keydown:ke.prototype.tb})]);var le=function(a){ke.call(this,a);this.Db=E(a.querySelector(".gs_md_in"));this.Fb=E(a.querySelector(".gs_md_tb .gs_lbl"))};la(le,ke);le.prototype.qa=function(){return B(this.i).querySelector(".gs_md_li[aria-selected]")};le.prototype.wb=function(a){me(this,a)};le.prototype.ta=function(a){var b=a.j.keyCode;13!=b&&32!=b||me(this,a)};
# var me=function(a,b){var c=b.currentTarget,d=B(a.Db),e=a.qa();c!=e&&(d.value=c.getAttribute("data-v"),B(a.Fb).innerHTML=c.innerHTML,e&&ne(e,!1),ne(c,!0));S(b);a.close();V("gs-change",d,b.j)},ne=function(a,b){y(a,"gs_sel",b);b?a.setAttribute("aria-selected","true"):a.removeAttribute("aria-selected")};Lc(le,[new T(".gs_md_ris",{}),new T(".gs_md_li",{click:le.prototype.wb,keydown:le.prototype.ta})]);U("#gs_lp","click",function(a){S(a);Od("gs_lp_d")});U("#gs_lp_cur","click",function(a){S(a);P("gs_lp_d")});var oe=function(a){this.Xa=E(a)};oe.prototype.ta=function(a){var b=a.currentTarget,c=a.j.keyCode;if(38==c||40==c){var d=B(this.Xa);d=jd(d,b,".gs_md_li",38==c)||jd(d,d,".gs_md_li",38==c)}else if(37==c||39==c)a:{c=!!(37==c^Fa(b.parentNode));d=b.parentNode;var e=d.children,f=e.length;if(d.id!=this.Xa){for(;e[--f]!=b;);d=hd(d,c)||gd(d.parentNode,c);e=d.children;if(f=Math.min(f+1,e.length))if(d=e[f-1],x(d,"gs_md_li")&&d.offsetLeft!=b.offsetLeft)break a}d=void 0}d&&(S(a),d.focus())};
# Lc(oe,[new T(".gs_md_ulr",{}),new T(".gs_md_li",{keydown:oe.prototype.ta})]);U("#gs_hdr_mnu","click",function(a){S(a);Od("gs_hdr_drw")});U("#gs_hdr_drw_mnu","click",function(a){S(a);P("gs_hdr_drw")});U("#gs_hdr_act_i","click",function(a){S(a);1==ua()?Ia(document.querySelector("#gs_hdr_drw_bot>a").href):jb("gs_hdr_act_d")});U("#gs_hdr_drw","keydown",function(a){var b=a.j.keyCode;if(38==b||40==b){var c=a.currentTarget;if(b=jd(c,c,".gs_md_li",38==b))S(a),b.focus()}});
# U("#gs_hdr_tsi",["focus","blur"],function(a){function b(){var g=d.getBoundingClientRect().top-10;10<Math.abs(g)&&window.scrollBy(0,g);clearTimeout(e);c()}function c(){M(window,f,b)}var d=a.target;a="focus"==a.type;y(B("gs_hdr"),"gs_hdr_ifc",a);if(a&&va&&!(749<window.innerHeight)){var e=setTimeout(c,1E3),f=["scroll","resize"];L(window,f,b)}});U("#gs_hdr_tsi",["input","gs-change"],function(a){y(B("gs_hdr_frm"),"gs_hdr_tsc",!!a.currentTarget.value)});
# U("#gs_hdr_tsc","mousedown",function(a){S(a);var b=B("gs_hdr_tsi");b.value="";b.focus();V("input",b,a.j)});U("#gs_hdr_sre","click",function(a){S(a);var b=B("gs_hdr");jb("gs_hdr_frm",function(){w(b,"gs_hdr_src");v(b,"gs_hdr_srx")},function(){v(b,"gs_hdr_src");w(b,"gs_hdr_srx")},B("gs_hdr_tsi"))});U(".gs_md_x","click",function(a){(a=a.currentTarget.getAttribute("data-mdx"))&&P(a)});var pe=function(){},qe,re;m=pe.prototype;m.qb=function(a){a.j.button||(S(a),se(a))};m.ua=function(a){te(a)&&(S(a),se(a))};m.xb=function(a){te(a)&&S(a)};m.va=function(a){if(!a.j.button){S(a);var b=a.j;b&&(ue=b.clientX||0,ve=b.clientY||0,L(document,we,xe,!0),clearTimeout(qe),qe=setTimeout(ye,2E3));se(a)}};m.Cb=function(a){S(a);if(ze){var b=a.j;if(b=(b=b&&b.touches)&&1==b.length&&b[0])Ae=b.clientX,Be=b.clientY,L(document,Ce,De,!0),clearTimeout(re),re=setTimeout(Ee,2E3)}se(a)};
# var te=function(a){a=a.j.keyCode;return 32==a||13==a},se=function(a){V("gs-press",a.currentTarget,a.j)},ye=function(){M(document,we,xe,!0);clearTimeout(qe);qe=void 0},xe=function(a){"mousedown"!=a.type&&10>Math.abs(a.clientX-ue)&&10>Math.abs(a.clientY-ve)?(bb(a),"click"==a.type&&ye()):ye()},Ee=function(){M(document,Ce,De,!0);clearTimeout(re);re=void 0},De=function(a){"touchstart"!=a.type&&10>Math.abs(a.clientX-Ae)&&10>Math.abs(a.clientY-Be)?(bb(a),"click"==a.type&&Ee()):Ee()},ue=0,ve=0,we=["mousedown",
# "mouseup","click"],ze=z("Android")&&!z("Chrome"),Ae=0,Be=0,Ce=["touchstart","mousedown","mouseup","click"];Lc(pe,[new T(".gs_press",{click:pe.prototype.qb,keydown:pe.prototype.ua,keyup:pe.prototype.xb,mousedown:pe.prototype.va,touchstart:pe.prototype.Cb})]);function Fe(a){Ge.style.left=He&&Ie===Je?a.left+"px":"auto";Ge.style.width=He?a.width+"px":"auto";V("gs-sth-change",B("gs_sth"))}function Ke(){var a=Le.getBoundingClientRect(),b=a.top,c=Ge.offsetHeight,d=0>b,e;if(e=d&&sa)e=document.activeElement,e=!!e&&"INPUT"==e.tagName&&"text"==e.type;b=e?-b-a.height:Je;var f=He!=d||Ie!==Je!=e;b!==Ie&&(Ie=b,Ge.style.transform=b===Je?"none":"translate3d(0,"+b+"px,0)");f&&(He=d,y(Me,"gs_sth_vis",d),y(Me,"gs_sth_trk",e),Fe(a),Le.style.height=He?c+"px":"auto")}
# function Ne(){He&&Fe(Le.getBoundingClientRect())}var Je,Me,Le,Ge,He=!1,Ie;N(function(){if(Me=B("gs_sth"))Le=Me.querySelector(".gs_sth_g"),Ge=Me.querySelector(".gs_sth_b"),Dd.addListener(Ke),Ed.addListener(Ne),Ke()});function Oe(a,b){var c=window.location.href,d=+Jb(c).authuser||0,e=help.service.Lazy.create(0,{apiKey:"AIzaSyBnsHNH76IH8vZplyq6wIQHlfHRq3blfB8",locale:"en-US"});e.requestSurvey({triggerId:a,authuser:d,enableTestingMode:b,callback:function(f){(f=f.surveyData)&&e.presentSurvey({surveyData:f,productData:{customData:{eventId:GSP.eventId,url:c}},colorScheme:1,authuser:d,customZIndex:1050,customLogoUrl:"https://scholar.google.com/scholar/images/scholar48.png"})}})}
# function Pe(a){var b=a();b.triggerId&&Ma(function(){return Oe(b.triggerId,b.Eb)})};(function(a){N(function(){return setTimeout(a,0)})})(function(){for(var a=q(document.querySelectorAll(".gs_invis")),b=a.next();!b.done;b=a.next())w(b.value,"gs_invis")});function Qe(a,b,c,d,e){c=void 0===c?0:c;d=void 0===d?1:d;e=void 0===e?5:e;for(var f,g,h=0;h<e;h++)f=(c+d)/2,g=a(f),g<b?c=f:d=f;return(c+d)/2}function Re(a){return a*a*(1.74-.74*a)}function Se(a){return a*a*(3-2*a)}function Te(a){return Qe(Se,a,Math.max(a-.1,0),Math.min(a+.1,1))}function Ue(a){var b=q(a);a=b.next().value;var c=b.next().value,d=b.next().value;b=1/(b.next().value-a)||0;return[0,(c-a)*b,(d-a)*b,1]}function Ve(a,b,c,d){var e=b-a;return d?[a,a+e*c]:[b-e*c,b]};function We(a){var b=document.querySelector(".gs_mylib .gs_ia_notf");b&&y(b,"gs_rdt",0<a)};function Xe(a,b){for(var c=a.length,d=window.innerWidth+"x"+window.innerHeight,e={},f=0;f<c;e={I:e.I},f++){var g=a[f];if(g){var h=g.indexOf("https://www.google-analytics.com/collect?");0==h?g+="&vp="+d:0==g.indexOf("/scholar_url?")&&(g+="&cd="+b+"&ws="+d);navigator.sendBeacon?0==h?(h=g.substr(41),g=g.substr(0,40),0<h.indexOf("&key=")&&(h=Hb(h),g="https://www.google-analytics.com/mp/collect?"+Gb({measurement_id:h.tid||"",api_secret:h.key||""}),h=JSON.stringify({client_id:h.cid||"",events:[{name:"page_view",
# params:{page_referrer:h.dr||"",page_location:h.dl||"",page_title:h.dt||""}}]})),navigator.sendBeacon(g,h)):navigator.sendBeacon(g):0!=h&&(e.I=new Image,Ye.push(e.I),e.I.onload=e.I.onerror=e.I.onabort=function(k){return function(){var l=Ye.indexOf(k.I);0>l||Ye.splice(l,1)}}(e),e.I.src=g)}}}var Ye=[];function Ze(){B("gs_asd_frm").submit()};function $e(a,b,c,d){var e=void 0===e?1:e;var f=Te(0),g=Te(e),h=f*(1.6*f*f-1.8*f+1.2);e=g*(1.6*g*g-1.8*g+1.2);var k=Ue([f*(1.6*f*f-1.8*f+1.2),1.6*f*f*g-.6*f*f-1.2*f*g+.8*f+.4*g,1.6*f*g*g-1.2*f*g+.4*f-.6*g*g+.8*g,g*(1.6*g*g-1.8*g+1.2)]);f=Ue([f*f*(3-2*f),f*(-2*f*g+f+2*g),g*(-2*f*g+2*f+g),g*g*(3-2*g)]);f="animation-timing-function:cubic-bezier("+[k[1],f[1],k[2],f[2]].join()+")";k=[];g=a.substring(1)+"_anm";k.push("@keyframes "+g+"{");h=Math.round(1E3*h)/10;e=Math.round(1E3*e)/10;.1<h&&k.push("0%{"+
# b+"}");k.push(h+"%{"+b+f+"}");k.push(e+"%{"+c+"}");k.push("100%{"+c+"}}");k.push(a+"{animation:"+g+" "+(d.toFixed(2)+"s linear;}"));return k.join("")}function af(a,b){function c(h){0===f&&(f=h);h=Math.min((h-f)/(1E3*b),1);var k=Math.min(Math.max(h,0),1);k=Qe(Re,h,k,Math.min(k+.17,1),5);window.scroll(e,d+Se(k)*g);1>h&&ab(c)}var d=window.pageYOffset,e=window.pageXOffset,f=0,g=a-d;ab(c)}
# function bf(a,b){if(a==b)return 0;var c=window.innerHeight,d=Math.abs(b-a);return 0>a&&0>b||a>c&&b>c?0:0<=a&&a<=c&&0<=b&&b<=c?d:0>a&&b>c||a>c&&0>b?c:0>a?b:0>b?a:a>c?c-b:c-a}
# ...
# q(Ve(c?r:0,c?0:-r,p,F));a=g.next().value;g=g.next().value;e=q(e);for(c=e.next();!c.done;c=e.next())l.push($e("#"+E(c.value),Oa(a),Oa(g),b));h.textContent=l.join("");h=function(){w(H,"gs_pfix");n.style.minHeight="";k()};Za(f,"animationend",h,1E3*b+100,h)}};function df(a){a&&a.querySelectorAll&&a.querySelectorAll(ef).length&&Ia(ff)}function gf(){df(document.body);hf=new MutationObserver(function(a){a=q(a);for(var b=a.next();!b.done;b=a.next())df(b.value.target)});hf.observe(document.body,{childList:!0,subtree:!0})}var hf,ef=[Ta("R8D02D50AD3,7@C>."),Ta(":7C2>6,4=2DDYlC6=:6G65."),Ta("2,52E2\\<@A6C?:@\\:5.")].join(),ff=Ta("^D49@=2C^<@A6C?:@]9E>=");function jf(a,b,c){var d=(B("gs_citd").getAttribute("data-u")||"").replace("{id}",a).replace("{p}",""+b);rc(d,"",function(e,f){O.gs_cit||(200==e?Od("gs_cit",d,"",f):bc($d()));c&&c()})}var kf;function lf(a,b,c,d){mf.notify({cb:a,Qa:b,Ya:c,error:d})}function nf(a,b){if(of)return!1;of=a;lf(a,b);return!0}function pf(a,b,c,d){var e=of="";if(c){e=b.split(":");b=e[0]||qf;e=e[1]||"";var f={};f[a+","+b]=e;rf(f)}lf(a,e,c,d)}
# function sf(){var a=G(B("gs_lbd_data"),"data-did"),b=G(B("gs_lbd_data"),"data-lid");if(nf(a,b)){var c=b?tf.replace("{id}",qf+":"+b):uf.replace("{id}",a);rc(c,"",function(d,e){a:{of="";var f="",g="";if(200==d)try{var h=JSON.parse(e)}catch(k){}(d=na(h))&&"number"==typeof h.NR&&We(h.NR);if(d){if(h.L){Ia(""+h.L);lf(a,b,!1,f);break a}if(h.M)f=""+h.M;else if(Array.isArray(h.U)&&1==h.U.length&&na(h.U[0]))g=""+(h.U[0].c||"");else if(!b||h.U)f=$d()}else f=$d();pf(a,g,!f,f)}})}}
# function vf(a){return(a=tb("s",void 0===a?!1:a))&&na(a)?a:{}}function rf(a){var b=J(),c=vf(!0),d;for(d in c){var e=c[d];e instanceof Array&&2==e.length&&12E5>b-e[1]||delete c[d]}for(var f in a)c[f]=[a[f],b];sb(ub,rb,"s",c)}var mf=new K,qf,tf,uf,of="";function Y(a){var b=B("gs_res_glb");return b?b.getAttribute(a)||"":""};function wf(){return B("gs_res_lbl_frm")}
# function xf(){yf("");for(var a=document.querySelectorAll("#gs_lbl_op .gs_in_cb"),b=a.length,c=[],d=[];b--;){var e=a[b];+e.getAttribute("data-s")!=zd(e)&&(zd(e)?c:d).push(e.getAttribute("data-id")||"")}a=B("gs_lbd_new-input");b=(b=document.querySelector("#gs_lbd_new_in .gs_in_cb"))&&zd(b);a=a&&b?a.value:null;if(!c.length&&!d.length&&null==a)return P("gs_md_albl-d"),!1;b=window.location;c={label_ids_to_add:c,label_ids_to_remove:d,label_name_add:a,"continue":b.pathname+b.search};d=wf();for(var f in c)a=
# Ha(d,f),null==c[f]?d.removeChild(a):a.value=c[f];return!0}function zf(a){var b=B("gs_lbd_new"),c=b.querySelector(".gs_in_cb");y(b,"gs_lbd_new_sel",a);a&&(Ad(c,1),B("gs_lbd_new-input").focus())}function Af(a){var b=B("gs_md_albl-d-t");y(b,"gs_lbl_hide",!a)}function Bf(a){var b=B("gs_md_albl-d").querySelector(".gs_md_ftr");y(b,"gs_lbl_hide",!a)}
# function Cf(a){var b=(Y("data-sval")||G(B("gs_ra_data"),"data-sval")).replace("{id}",a).replace("%7Bid%7D",a);rc(b,"",function(c,d){var e="";if(200==c)if(c=document.createElement(Aa.ea),c.innerHTML=d,c=c.querySelector(".gs_md_prg .gs_alrt"))(d=G(c,"data-r"))?Ia(d):e=c.innerHTML;else{Af(!0);Bf(!0);Od("gs_md_albl-d",b,"",d);return}else e=$d();pf(a,"",!1,e)})}function yf(a){var b=B("gsc_lbd_alrt")||B("gs_md_albl-d").querySelector(".gs_md_prg .gs_alrt");b&&(b.innerHTML=a)};var Z=function(a){this.R=a;this.bb=G(a,"data-cid");this.La=Df(a);this.Ga=Ef(a)};Z.prototype.yb=function(a){y(a.currentTarget.parentNode,"gs_or_mvi")};Z.prototype.pb=function(a){var b=a.currentTarget;x(b,"gs_or_ldg")||(y(b,"gs_or_ldg",!0),jf(this.bb,this.Ga,function(){y(b,"gs_or_ldg",!1)}))};Z.prototype.gb=function(a){var b=a.currentTarget,c=b.parentNode;jb(E(b),function(){w(b,"gs_press");v(c,"gs_vis");v(b,"gs_anm")},function(){v(b,"gs_press");w(c,"gs_vis")})};
# Z.prototype.Na=function(){var a=G(this.R,"data-lid");nf(this.La,a)&&Cf(this.La)};var Ff=[new T(".gs_or",{}),new T(".gs_or_ggsm",{"gs-press":Z.prototype.gb}),new T(".gs_or_cit",{click:Z.prototype.pb}),new T(".gs_or_sav",{click:Z.prototype.Na}),new T(".gs_or_lbl",{click:Z.prototype.Na}),new T(".gs_or_mor",{click:Z.prototype.yb})];
# function Gf(){for(var a=x(document.documentElement,"gs_el_ph"),b=document.querySelectorAll(".gs_or_ggsm"),c=b.length;c--;){var d=b[c];x(d,"gs_vis")&&P(E(d));y(d,"gs_press",a);w(d,"gs_anm")}}function Hf(a){var b=document.querySelector('.gs_or[data-did="'+a.cb+'"]');if(b){var c=b.querySelector(".gs_or_sav")||b.querySelector(".gs_or_lbl");c&&(y(c,"gs_or_ldg",void 0===a.error),a.Ya&&b.setAttribute("data-lid",a.Qa))}}function Df(a){return G(a,"data-did")}function Ef(a){return+G(a,"data-rp")||0};function If(){Kc("#gsb_promo_x",function(a){B("gsb_promo").className="";S(a);rc(a.target.href,"",function(){})});L(window,"message",function(a){var b=a.data,c;a.origin.match(/[.]google[.]com(:[0-9]+)?$/)&&b&&"object"==typeof b&&0<=(c=+b.gsbPromo)&&(B("gsb_promo").className=c?"gsb_not_installed":"gsb_installed")});N(function(){var a=document.createElement("iframe");a.id="gsb_promo_ping";a.frameBorder="0";a.scrolling="no";a.tabIndex=-1;a.src=(window.location.host.indexOf("scholar.google.")?"":"//scholar.google.com")+
# "/scholar_gsb_promo_ping";document.body.appendChild(a)})};var Jf=function(a){this.R=a;this.na=a.querySelector(".gs_fma_con");this.ga=a.querySelector(".gs_fma_abs");this.ra=a.querySelector(".gs_fma_grad");this.Za=a.querySelector(".gs_fma_brdr");this.Jb=a.querySelector(".gs_fma");this.Ob=a.querySelector(".gs_fma_sml");this.eb=a.querySelector(".gs_flb");this.Ga=Ef(this.R)};
# Jf.prototype.Ab=function(){var a=this,b=!x(this.na,"gs_fma_ex"),c=[B("gs_res_ccl_bot"),this.eb],d=id(this.R);d=q(d);for(var e=d.next();!e.done;e=d.next())c.push(e.value);b&&Kf(this.Jb,this.Ga);var f=Ka("gs_fma_anmst");cf(this.na,this.ga,function(){a.ra.style.height=a.ga.scrollHeight+"px";v(a.ga,"gs_fma_ovis");return y(a.na,"gs_fma_ex",b)},[this.Ob],c,this.ra,this.Za,f,function(){f.parentNode.removeChild(f);a.ra.style.height="";w(a.ga,"gs_fma_ovis")})};
# var Kf=function(a,b){a=a.getAttribute("data-trk").split(" ");Xe(a,b)},Lf=[new T(".gs_fmar",{}),new T([".gs_fma_sml_a"],{click:Jf.prototype.Ab})],Mf=!1;
# function Nf(){for(var a=q(document.querySelectorAll(".gs_fmar")),b=a.next();!b.done;b=a.next())b=b.value,y(b.querySelector(".gs_fma_con"),"gs_fma_cl",126<b.querySelector(".gs_fma_abs").scrollHeight-45);b=document.querySelectorAll(".gs_fmar");if(!(Mf||!navigator.sendBeacon||0==b.length||0>=b[0].querySelector(".gs_fma").offsetHeight)&&(Mf=!0,a=Y("data-fmat"))){b=q(b);for(var c=b.next();!c.done;c=b.next()){c=c.value;var d=Ef(c);a+=["&rp",d,"=",x(c.querySelector(".gs_fma_con"),"gs_fma_cl")?"0":"1"].join("")}navigator.sendBeacon(a)}}
# ;var Of=function(a){this.R=a};Of.prototype.zb=function(){5>Ef(this.R)?Pf({}):(Qf=Df(this.R),Rf=J())};function Sf(){var a=document.location.href;return a.substr(0,a.indexOf("#"))||a}function Tf(){return document.querySelector(".gs_r_rfr")}function Uf(a){var b=Tf();return!!b&&Df(b)==a&&!!b.querySelector(".gs_rfr")}function Pf(a){sb(ub,rb,"rfr",a)}function Vf(){var a=tb("rfr");return a&&na(a)?a:null}
# function Wf(a,b,c){v(a,"gs_r_rfr");var d=document.createElement(Aa.ea);d.className="gs_rfr";d.innerHTML=b;a.appendChild(d);Xf();if(c){b="@keyframes gs_r_vsld_anm{0%{transform:translate(0,-"+d.offsetHeight+"px);}100%{transform:translate(0,0);}}";Ka("gs_r_vsld_style").textContent=b;b=id(a);b=q(b);for(c=b.next();!c.done;c=b.next())v(c.value,"gs_r_vsld");v(B("gs_res_ccl_bot"),"gs_r_vsld");v(a,"gs_anm");Za(d,"animationend",Yf,500,Yf)}}
# function Yf(){var a=Tf();a&&w(a,"gs_anm");a=document.querySelectorAll(".gs_r_vsld");for(var b=a.length,c=0;c<b;c++)w(a[c],"gs_r_vsld")}function Zf(){var a=Tf();if(!a)return!1;w(a,"gs_r_rfr");var b=a.querySelector(".gs_rfr");if(!b)return!1;a.removeChild(b);return!0}function $f(){var a=window.pageYOffset,b=Tf();if(!b)return a;b=b.querySelector(".gs_rfr");if(!b)return a;b=b.getBoundingClientRect();0>b.top&&(a-=b.bottom-b.top);return a}
# function ag(a,b){var c=b.getBoundingClientRect();b=c.bottom;c=b-(b-c.top)/3;var d=1E4,e=-1E4,f=!1;a=a.getClientRects();for(var g=0;g<a.length;g++){var h=a[g];4<=b-h.top&&4<=h.bottom-c?(d=Math.min(d,h.left),e=Math.max(e,h.right)):h.top>=b&&(f=!0)}return 1E4==d?f?0:-1:f?e-d:-1}
# function Xf(){for(var a=document.querySelectorAll(".gs_rfr_rt>a"),b=0;b<a.length;b++){var c=a[b],d=c.parentNode,e=d.firstElementChild,f=e.style;c=c.querySelector("[dir]")||c;f.display="none";var g=ag(c,d);if(0<=g){var h=Fa(d),k=Fa(c);f.display="block";e.setAttribute("dir",k?"rtl":"ltr");g=ag(c,d);f.transform="translateX("+[-1,0,0,1][2*h+k]*(d.offsetWidth-e.offsetWidth-g)+"px)"}}}var bg=[new T([".gs_r"],{}),new T([".gs_rt",".gs_or_ggsm"],{click:Of.prototype.zb})],Qf,Rf;GSP.customAC&&(Lc(W,xd),N(yd),L(window,"pageshow",function(){setTimeout(yd,0)}));window.MutationObserver&&N(gf);U("#gs_asd_psb","click",Ze);U("#gs_asd_frm","keydown",function(a){var b=a.target;"INPUT"==b.tagName&&"text"==b.type&&13==a.j.keyCode&&Ze()});U(".gs_citr","focus",function(a){var b=a.currentTarget;b!=kf&&(kf=b,S(a),setTimeout(function(){window.getSelection().selectAllChildren(b);b.focus()},0))});U(".gs_cith","click",function(a){(a=a.currentTarget.parentNode.querySelector(".gs_citr"))&&a.focus()});
# U("#gs_lbd_apl","click",function(){xf()&&V("submit",wf())});Kc("#gs_lbd_new_btn",function(){zf(!0)});Kc("#gs_lbd_new_cb",function(){zf(!1)});U("#gs_lbd_trash","click",function(){sf()});U("#gs_md_albl-d","gs-md-lded",function(){B("gs_lbd_data")?(L(wf(),"submit",xf),pf(G(B("gs_lbd_data"),"data-did"),Ha(wf(),"s").value,!0,"")):(Af(!1),Bf(!1))});U("#gs_res_lbl_frm","gs-ajax-form-done",function(){var a=G(wf(),"data-p");(a=/^NR:([0-9]+)$/.exec(a))&&We(parseInt(a[1],10)||0)});
# mf.add(function(a){void 0===a.error?(gc=0,ec(),yf("")):a.error?O["gs_md_albl-d"]?yf(a.error):bc(a.error):a.Ya&&!a.Qa&&P("gs_md_albl-d")});Lc(Z,Ff);
# N(function(){Gf();mf.add(Hf);for(var a={},b=document.querySelectorAll(".gs_or[data-did]"),c=b.length;c--;){var d=b[c],e=Df(d);d=G(d,"data-lid");a[e]=d}b=Y("data-lpu");c=Y("data-sva");e=Y("data-tra");d=Y("data-lsl");qf=b;tf=e;uf=c;try{var f=JSON.parse(void 0===d?"":d)}catch(h){}f&&na(f)&&!Zb||(f={});rf(f);f=vf();for(var g in a)b=a[g],c=f[g+","+qf],c instanceof Array&&(c=""+c[0],b!=c&&(b=c,lf(g,b,!0,"")))});Fd.add(Gf);Gf();L(window,"pagehide",Gf);
# U("#gs_res_sb_yyc","click",function(){B("gs_res_sb_yyf").style.display="block";for(var a=document.querySelectorAll("#gs_res_sb_yyl>li"),b=a.length;b--;)y(a[b],"gs_bdy_sb_sel",b==a.length-1)});U("#gs_scipsc","gs-change",function(a){var b=zd(a.currentTarget),c=Ha(B("gs_hdr_frm"),"scipsc"),d=Ha(B("gs_asd_frm"),"scipsc");c.value=d.value=b?"1":"";a=a.currentTarget.getAttribute("data-msg")||"";B("gs_hdr_tsi").placeholder=b?a:""});
# (function(a){window.location.hash||Zb||N(function(){return Pe(a)})})(function(){var a=Y("data-usv");return{triggerId:a&&"FQCrQs2JV0iDFprtVEw0WZEm7Syp",Eb:"1"==a}});Kc("#gs_res_drw_adv",function(){Od("gs_asd")});N(function(){var a=Y("data-ttl");a&&(document.title=a);a=new zc("q");var b=Y("data-ahq");b&&a.add(b);Y("data-gsb")&&If()});Lc(Of,bg);L(window,"pagehide",function(){Yf();if(Qf&&!Uf(Qf)){var a={d:Qf,u:Sf(),t:J()};5E3<=J()-Rf&&(a={});var b=$f();Zf()&&window.scrollTo(0,b);a.s=b;Pf(a)}});
# L(window,"pageshow",function(){var a=Vf(),b=Sf();if(a&&a.u==b)if(864E5<=J()-(+a.t||0))Pf({});else{var c=""+a.d,d=Y("data-rfr");if(d)if(Uf(c))Xf();else{b=Zf();var e=+a.s;e&&!b&&(z("Trident")||z("Edge"))&&Za(window,"scroll",function(){window.scrollTo(0,e)},20);a.s=0;Pf(a);var f=document.querySelector('.gs_or[data-did="'+c+'"]');f&&((b=a.h)?Wf(f,""+b,!1):setTimeout(function(){var g=d.replace("{id}",c),h=rc(g,"",function(l,n){200==l&&n&&(Wf(f,n,!0),a.h=n,a.t=J(),Pf(a));clearTimeout(k)}),k=setTimeout(function(){sc(h)},
# 1E3)},0))}}});Ed.addListener(Xf);N(function(){Nf();Ed.addListener(Nf)});Lc(Jf,Lf);
# }({"customAC":2,"eventId":"JHi4ZKiIJ9KsmgG92oGgCA"});</script></head><body><div id="gs_top" onclick=""><style>#gs_md_s,.gs_md_wnw{z-index:1200;position:fixed;top:0;left:0;width:100%;height:100%;visibility:hidden;}.gs_md_ds:before{content:'';position:absolute;background-color:#fff;z-index:100;opacity:0;visibility:hidden;top:0;bottom:0;right:0;left:0;}.gs_md_ds.gs_md_d:not(.gs_el_ph .gs_md_wmw):before{top:-1px;bottom:-1px;right:-1px;left:-1px;}#gs_md_s{background-color:#fff;opacity:0;}.gs_el_ta #gs_md_s,.gs_el_ph #gs_md_s,.gs_el_ta .gs_md_ds:before,.gs_el_ph .gs_md_ds:before{background-color:#666;}#gs_md_s.gs_vis,.gs_md_ds.gs_md_ins_vis:before{opacity:.5;visibility:visible;}.gs_md_wnw{transition:all 0s .218s;}.gs_md_wnw.gs_vis{visibility:visible;transition:all 0s;}.gs_el_tc .gs_md_ds:before{transition:opacity .15s,visibility 0s .15s;}.gs_el_tc .gs_md_ds.gs_md_ins_vis:before{transition:opacity .218s,visibility 0s;}.gs_md_wnw>.gs_md_d{position:relative;margin:0 auto;width:464px;box-shadow:2px 2px 8px rgba(0,0,0,.2);white-space:normal;}.gs_el_ta .gs_md_wnw>.gs_md_d,.gs_el_ph .gs_md_wnw>.gs_md_d{box-shadow:2px 2px 8px rgba(0,0,0,.65);}.gs_el_ph .gs_md_wnw>.gs_md_d{width:80%;max-width:440px;}.gs_el_ph .gs_md_wmw>.gs_md_d{display:flex;flex-direction:column;width:100%;height:100%;max-width:none;border:none;box-shadow:none;transform:translate(0,100%);transform:translate(0,100vh);transition:transform .27s cubic-bezier(.4,0,.6,1),opacity 0s .27s,visibility 0s .27s,max-height 0s .27s;}.gs_el_ph .gs_md_wmw>.gs_md_d.gs_vis{transform:translate(0,0);transition:transform .3s cubic-bezier(0,0,.2,1);}.gs_md_wmw>.gs_md_d.gs_abt,.gs_el_ph .gs_md_wmw>.gs_md_d.gs_abt{transition:none;}.gs_md_hdr{display:flex;align-items:center;height:47px;border-bottom:1px solid #e0e0e0;border-bottom-color:rgba(0,0,0,.12);background-color:#f5f5f5;}.gs_md_hdr>a,.gs_md_hdr>a.gs_btn_lrge{flex:0 0 auto;width:41px;height:47px;}.gs_el_ph .gs_md_hdr>a{margin:0 2px 0 0;}.gs_el_ph a.gs_md_hdr_c{margin:0 0 0 2px;}.gs_md_hdr_b{margin:0 41px 0 16px;}.gs_el_ph .gs_md_hdr_b{margin:0 16px;}.gs_md_hdr_t:empty~.gs_md_hdr_b{margin-left:0;}.gs_md_hdr_b:empty{width:41px;margin:0;}.gs_el_ph .gs_md_hdr_b:empty{margin-right:2px;}.gs_md_hdr_b:empty:not(:last-child){display:none;}.gs_md_hdr_b>button{min-width:51px;height:33px;}.gs_md_hdr_t{flex:1 1 auto;font-size:18px;font-weight:normal;color:#666;overflow:hidden;text-overflow:ellipsis;white-space:nowrap;text-align:center;}.gs_md_bdy{position:relative;overflow-y:auto;box-sizing:border-box;padding:24px 41px 0 41px;}.gs_md_bdy:after{display:block;content:"";clear:both;padding-bottom:24px;}.gs_el_ph .gs_md_bdy{padding:16px 16px 0 16px;}.gs_el_ph .gs_md_bdy:after{padding-bottom:16px;}.gs_el_ph .gs_md_wmw .gs_md_bdy{flex:1;}.gs_md_ftr{border-top:1px solid #e0e0e0;}.gs_md_lbl{display:block;font-size:16px;margin:0 0 16px 0;word-wrap:break-word;}.gs_md_btns{margin:24px 0 0 0;white-space:nowrap;}.gs_el_ph .gs_md_btns{margin:16px 0 0 0;}.gs_md_btns button{margin-right:16px;}.gs_md_btns button:last-child{margin-right:0;}.gs_md_prg{margin:24px 0;text-align:center;}.gs_md_prg .gs_alrt{padding:4px 16px;}.gs_md_ldg:before{content:"";position:absolute;top:0;left:0;bottom:0;right:0;background-color:#fff;opacity:.5;z-index:100;}</style><div id="gs_md_ldg" style="display:none">Loading...</div><div id="gs_md_err" style="display:none">The system can't perform the operation now. Try again later.</div><div id="gs_md_s"></div><div class="gs_md_wnw gs_md_ds gs_md_wmw" data-h="0"><div aria-labelledby="gs_cit-t" class="gs_md_d gs_md_ds gs_ttzi" data-cid="gs_citd" data-wfc="gs_cit-x" id="gs_cit" role="dialog" tabindex="-1"><div class="gs_md_hdr"><a aria-label="Cancel" class="gs_btnCLS gs_md_x gs_md_hdr_c gs_in_ib gs_btn_lrge" data-mdx="gs_cit" href="javascript:void(0)" id="gs_cit-x" role="button"><span class="gs_ico"></span><span class="gs_ia_notf"></span><span class="gs_lbl"></span></a><h2 class="gs_md_hdr_t" id="gs_cit-t">Cite</h2><div class="gs_md_hdr_b"></div></div> ...
# Searching Google Scholar complated!
# Searching Web of Science...
# Searching Web of Science complated!
# Searching PubMed Central PMC...
# Searching PubMedd Central PMC complated!
# Searching Europe PMC...
# Searching Europe PMC complated!

# %%
if __name__ == "__main__":
    # merge all search results
    LS.merge_search_results()
    
    # send .PDF publication of all potential related literatures to ChatPDF.con and ask for relatedness 
    # then record the answer to the list_of_potential_related_literature.csv as well
    # ChatPDF_relatedness(path_urls, chatpdf_related_queries)

    # now we have a list of potential related literature and the information about relatedness 
    # stored in the file "list_of_potential_related_literature.csv"
    # now we may perform a automatic filtering and manual filtering of the literature

    # automatic filtering
    #auto_filter(path_potential)

    # manual filtering
    # manual_filter(path_potential, path_related_urls)
# Out:
# 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 if __name__ == "__main__":
#       2     # merge all search results
# ----> 3     LS.merge_search_results()
#
# File ~/myProjects/didihou_master_project/semi_automated_literature_search.py:173, in merge_search_results()
#     170 doi_df.to_csv(FPM.path_poten_csv)
#     172 # eliminate duplicates
# --> 173 doi_df = pd.read_excel(FPM.path_poten_csv)
#     174 print(doi_df.head())
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/pandas/io/excel/_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#
# File ~/anaconda3/envs/myenv/lib/python3.10/site-packages/pandas/io/excel/_base.py:1500, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1496     ext = inspect_excel_format(
#    1497         content_or_path=path_or_buffer, storage_options=storage_options
#    1498     )
#    1499     if ext is None:
# -> 1500         raise ValueError(
#    1501             "Excel file format cannot be determined, you must specify "
#    1502             "an engine manually."
#    1503         )
#    1505 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1506 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.

# %%
'''
# test the redirect of the urls
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'} 

response_pdf = requests.get('https://doi.org/10.1016/j.neuron.2020.01.005', allow_redirects=True, headers = headers)
print(response_pdf.history)
print(response_pdf.url)
response_pdf_1 = requests.get('https://linkinghub.elsevier.com/retrieve/pii/S0896627320300052', allow_redirects=True, headers = headers)
print(response_pdf_1.history)
print(response_pdf_1.url)


response_pdf = requests.get('https://onlinelibrary.wiley.com/doi/10.1111/ejn.13910', headers = headers)
soup_pdf = BeautifulSoup(response_pdf.content,'lxml')
print(soup_pdf)
'''

# %% [markdown]
# This is the end of semi-automated literature search.

# %% [markdown]
# Now we have a list of actually related literature stored in list_of_related_literature.txt

# %% [markdown]
# Next step: we perform a information search on the list of related literature
# We have a list of actually related literature at the moment, now we need to extract information we need from the literature. We intend to achieve this with a combination of automated searching and manual extraction

# %%
# semi-automated information search

# %%
import re
if '//doi.org/' in 'https://doi.org/10.1016/0165-0173(96)00003-3':
    print("yes")
